# %%
from runlmc.models.lmc import LMC, interp_cubic
from runlmc.kern.rbf import RBF
from paramz.optimization import Optimizer
import numpy as np
import math
import numpy as np
import scipy
import scipy.sparse 
from scipy.spatial.distance import cdist

# %matplotlib inline 
import matplotlib.pyplot as plt

np.random.seed(1234)

# %%
n_per_output = [65, 100, 75]
ngrid = sum(n_per_output) // len(n_per_output) * 10
xss = list(map(np.random.rand, n_per_output))
nout = len(n_per_output)
yss = [np.sin(2 * np.pi * xs + i * 2 * np.pi / nout) + np.random.randn(len(xs)) * 0.05
       for i, xs in enumerate(xss)]
ks = [RBF(name='rbf{}'.format(i)) for i in range(nout)]

# %%
def print_diagram(lmc):
    plot_xs =  np.arange(0, 1, 0.01)
    ys, var = lmc.predict([plot_xs for _ in range(nout)])
    for i, (y, v, xs, ys) in enumerate(zip(ys, var, xss, yss)):
        sd = np.sqrt(v)
        order = xs.argsort()
        plt.scatter(xs[order], ys[order])
        plt.title('output {} (95%)'.format(i))
        plt.plot(plot_xs, y)
        plt.plot(plot_xs, y + 2 * sd, ls='--', c='g')
        plt.plot(plot_xs, y - 2 * sd, ls='--', c='g')
        plt.show()

# %%
# Unoptimized
lmc = LMC(xss, yss, kernels=ks, normalize=False)
print(lmc)
print_diagram(lmc)
# Out:
# Name : lmc
# Objective : 340.10028997574796
# Number of Parameters : 18
# Number of Optimization Parameters : 18
# Updates : True
# Parameters:
#   lmc.                  |  value  |  constraints  |  priors
#   rbf0.variance         |    1.0  |      +ve      |
#   rbf0.inv_lengthscale  |    1.0  |      +ve      |
#   rbf1.variance         |    1.0  |      +ve      |
#   rbf1.inv_lengthscale  |    1.0  |      +ve      |
#   rbf2.variance         |    1.0  |      +ve      |
#   rbf2.inv_lengthscale  |    1.0  |      +ve      |
#   a0                    |   (3,)  |               |
#   a1                    |   (3,)  |               |
#   a2                    |   (3,)  |               |
#   noise                 |   (3,)  |      +ve      |

# %%
import scipy.optimize as sciopt
class DerivFree(Optimizer):
    def __init__(self):
        super().__init__()

    def opt(self, x_init, f_fp=None, f=None, fp=None):
        options = {'iprint': 1, 'disp': True, 'maxiter': 10000}
        res = sciopt.minimize(
            f,
            x_init,
            method='COBYLA',
            options=options)
        print(res.message)
        self.x_opt = res.x
    
lmc.optimize(optimizer=DerivFree())
# Out:
# Optimization terminated successfully.

# %%
#optimized
print(lmc)
print(lmc.noise)
print_diagram(lmc)
# Out:
# Name : lmc
# Objective : -187.63575446483387
# Number of Parameters : 18
# Number of Optimization Parameters : 18
# Updates : True
# Parameters:
#   lmc.                  |           value  |  constraints  |  priors
#   rbf0.variance         |   1.54671598755  |      +ve      |
#   rbf0.inv_lengthscale  |    3.3528777103  |      +ve      |
#   rbf1.variance         |  0.673196171567  |      +ve      |
#   rbf1.inv_lengthscale  |   6.36807774451  |      +ve      |
#   rbf2.variance         |   1.07371923195  |      +ve      |
#   rbf2.inv_lengthscale  |   6.89724463224  |      +ve      |
#   a0                    |            (3,)  |               |
#   a1                    |            (3,)  |               |
#   a2                    |            (3,)  |               |
#   noise                 |            (3,)  |      +ve      |
#   index  |     lmc.noise  |  constraints  |  priors
#   [0]    |    0.00628986  |      +ve      |
#   [1]    |    0.00628890  |      +ve      |
#   [2]    |    0.00628933  |      +ve      |

# %% [markdown]
# GPy on the same problem with the same kernels.
#
# Note GPy LMC is slightly different because GPy adds a full-rank diagonal coregionalization to each
# kernel.

# %%
import GPy

rbfs = [GPy.kern.RBF(1) for _ in range(nout)]
# not exactly the same since mine is rank-1 only for now
# This is why we need as many kernels as outputs, because we'd be rank-deficient o/w
k = GPy.util.multioutput.LCM(input_dim=1,num_outputs=nout,kernels_list=rbfs)
xss_reshaped = [xs.reshape(-1, 1) for xs in xss]
yss_reshaped = [ys.reshape(-1, 1) for ys in yss]
m = GPy.models.GPCoregionalizedRegression(
    xss_reshaped, yss_reshaped, kernel=k)
m.optimize()
print(m)
# Out:
# Name : gp
# Objective : -357.5407608199333
# Number of Parameters : 27
# Number of Optimization Parameters : 27
# Updates : True
# Parameters:
#   gp.                                    |              value  |  constraints  |  priors
#   sum.ICM0.rbf.variance                  |   5.9533513159e-08  |      +ve      |
#   sum.ICM0.rbf.lengthscale               |    0.0448527941803  |      +ve      |
#   sum.ICM0.B.W                           |             (3, 1)  |               |
#   sum.ICM0.B.kappa                       |               (3,)  |      +ve      |
#   sum.ICM1.rbf.variance                  |  0.000286964994465  |      +ve      |
#   sum.ICM1.rbf.lengthscale               |     0.319556212323  |      +ve      |
#   sum.ICM1.B.W                           |             (3, 1)  |               |
#   sum.ICM1.B.kappa                       |               (3,)  |      +ve      |
#   sum.ICM2.rbf.variance                  |   0.00023977509631  |      +ve      |
#   sum.ICM2.rbf.lengthscale               |     0.316828422419  |      +ve      |
#   sum.ICM2.B.W                           |             (3, 1)  |               |
#   sum.ICM2.B.kappa                       |               (3,)  |      +ve      |
#   mixed_noise.Gaussian_noise_0.variance  |   0.00211398649919  |      +ve      |
#   mixed_noise.Gaussian_noise_1.variance  |   0.00162060853496  |      +ve      |
#   mixed_noise.Gaussian_noise_2.variance  |   0.00226582451313  |      +ve      |

# %%
# Plotting code adapted from GPy coregionalization tutorial
# Also 95% confidence

data_rows = np.add.accumulate(n_per_output)
data_rows = np.insert(data_rows, 0, 0)

for i in range(nout):
    m.plot(
        plot_limits=(0, 1),
        fixed_inputs=[(1,i)],
        which_data_rows=slice(data_rows[i],data_rows[i + 1]))
# Out:
#  /usr/local/lib/python3.5/dist-packages/matplotlib/figure.py:1744: UserWarning:This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
